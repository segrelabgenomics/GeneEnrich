# %% [markdown]
# This notebook details the parsing of the mouse gene set from Mouse Genome Informatics (MGI).

# %%
import pandas as pd

# %%
mouse_file = '../files/MGI_PhenoGenoMP_Jan16_2020.rpt'

# %%
# read in mouse file and add appropriate columns 
# see MGI_PhenoGenoMP.rpt in 
#http://www.informatics.jax.org/downloads/reports/index.html

mouse = pd.read_csv(mouse_file,header=None,sep='\t')
mouse.columns = ["Allelic_Composition", "AlleleSymbol",
                 "Genetic_Background","Mammalian_Phenotype_ID",
                 "PubMed_ID","MGI_Marker_Accession_ID"]
mouse.head()
# Out:
#        Allelic_Composition AlleleSymbol     Genetic_Background  \
# 0  Rb1<tm1Tyj>/Rb1<tm1Tyj>  Rb1<tm1Tyj>  involves: 129S2/SvPas
# 1  Rb1<tm1Tyj>/Rb1<tm1Tyj>  Rb1<tm1Tyj>  involves: 129S2/SvPas
# 2  Rb1<tm1Tyj>/Rb1<tm1Tyj>  Rb1<tm1Tyj>  involves: 129S2/SvPas
# 3  Rb1<tm1Tyj>/Rb1<tm1Tyj>  Rb1<tm1Tyj>  involves: 129S2/SvPas
# 4  Rb1<tm1Tyj>/Rb1<tm1Tyj>  Rb1<tm1Tyj>  involves: 129S2/SvPas
#
#   Mammalian_Phenotype_ID PubMed_ID MGI_Marker_Accession_ID
# 0             MP:0000600  12529408               MGI:97874
# 1             MP:0001716  16449662               MGI:97874
# 2             MP:0001698  16449662               MGI:97874
# 3             MP:0001092  16449662               MGI:97874
# 4             MP:0000961  16449662               MGI:97874

# %%
len(mouse["MGI_Marker_Accession_ID"].unique())
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-79-6d9d404bd9ca> in <module>
# ----> 1 len(mouse["MGI_Marker_Accession_ID"].unique())
#
# ~/.conda/envs/py39/lib/python3.9/site-packages/pandas/core/series.py in unique(self)
#    1870         Categories (3, object): ['a' < 'b' < 'c']
#    1871         """
# -> 1872         result = super().unique()
#    1873         return result
#    1874
#
# ~/.conda/envs/py39/lib/python3.9/site-packages/pandas/core/base.py in unique(self)
#    1045                     result = np.asarray(result)
#    1046         else:
# -> 1047             result = unique1d(values)
#    1048
#    1049         return result
#
# ~/.conda/envs/py39/lib/python3.9/site-packages/pandas/core/algorithms.py in unique(values)
#     405
#     406     table = htable(len(values))
# --> 407     uniques = table.unique(values)
#     408     uniques = _reconstruct_data(uniques, original.dtype, original)
#     409     return uniques
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.unique()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable._unique()
#
# TypeError: unhashable type: 'list'

# %%
#number of rows in table
len(mouse)
# Out:
# 326735

# %%
#number of unique mammalian phenotype IDs
len(mouse["Mammalian_Phenotype_ID"].unique())
# Out:
# 10302

# %%
# some rows have more than one MGI_Marker_Accession_ID
# explode columns

mouse["MGI_Marker_Accession_ID"] = mouse["MGI_Marker_Accession_ID"].apply(lambda x: x.split(","))
mouse_mgi_ids = mouse[["Mammalian_Phenotype_ID","MGI_Marker_Accession_ID"]].copy()
mouse_mgi_ids = mouse_mgi_ids.explode("MGI_Marker_Accession_ID")

# %%
len(mouse_mgi_ids)
# Out:
# 412443

# %%
#from quick visualization, we see that the MGI_Marker_Accession_ID is not unique
# mouse_mgi_ids_parsed
mouse_mgi_ids = mouse_mgi_ids.drop_duplicates("MGI_Marker_Accession_ID")
mouse_mgi_ids["MGI_Marker_Accession_ID"].to_csv("MGI_ID_unique_Jan16_2020.txt",
                                                       index=None, header=False)
len(mouse_mgi_ids)
# Out:
# 20719

# %%
# obtained table 
# http://www.informatics.jax.org/batch
mgi_batch_report = pd.read_csv("../files/MGIBatchReport_20200116_133654.txt",sep="\t")
print(len(mgi_batch_report))
mgi_batch_report_na = mgi_batch_report.loc[mgi_batch_report["MP ID"].isna()]
print(len(mgi_batch_report_na))
mgi_batch_report_na.head()
# Out:
# 230895
# 1735
#              Input Input Type MGI Gene/Marker ID Symbol  \
# 20358  MGI:1346096        MGI        MGI:1346096  Estq3
# 20359  MGI:1346095        MGI        MGI:1346095  Estq2
# 20657  MGI:1346081        MGI        MGI:1346081  Estq4
# 20658  MGI:1346097        MGI        MGI:1346097  Estq1
# 23712    MGI:96947        MGI          MGI:96947   Mdac
#
#                                      Name                 Feature Type  \
# 20358  estradiol regulated response QTL 3                          QTL
# 20359  estradiol regulated response QTL 2                          QTL
# 20657  estradiol regulated response QTL 4                          QTL
# 20658  estradiol regulated response QTL 1                          QTL
# 23712                     modifier of Dac  heritable phenotypic marker
#
#       Ensembl ID  Entrez Gene ID MP ID Term
# 20358        NaN        112297.0   NaN  NaN
# 20359        NaN        109458.0   NaN  NaN
# 20657        NaN        112296.0   NaN  NaN
# 20658        NaN        109459.0   NaN  NaN
# 23712        NaN         17238.0   NaN  NaN

# %%
mgi_batch_report_parsed = mgi_batch_report[["MP ID","Term", "MGI Gene/Marker ID"]].copy()
mgi_batch_report_parsed["Term"] = mgi_batch_report_parsed["Term"].str.replace(" ","_")
mgi_batch_report_parsed["pathway"] = mgi_batch_report_parsed["MP ID"]+"_"+mgi_batch_report_parsed["Term"]
mgi_batch_report_parsed = mgi_batch_report_parsed.sort_values("pathway")
mgi_batch_report_parsed.columns = ["mp","term","mgi", "geneset"]
mgi_batch_report_parsed["database"] = "MGI"
mgi_batch_report_parsed = mgi_batch_report_parsed[["database","geneset", "mgi", "mp"]]

mgi_batch_report_parsed = mgi_batch_report_parsed.dropna()
print(len(mgi_batch_report_parsed))
mgi_batch_report_parsed.head()
# Out:
# 229160
#        database                                        geneset          mgi  \
# 83736       MGI  MP:0000003_abnormal_adipose_tissue_morphology  MGI:1349717
# 103676      MGI  MP:0000003_abnormal_adipose_tissue_morphology   MGI:101884
# 40413       MGI  MP:0000003_abnormal_adipose_tissue_morphology   MGI:895149
# 16235       MGI  MP:0000003_abnormal_adipose_tissue_morphology  MGI:1099809
# 188573      MGI  MP:0000003_abnormal_adipose_tissue_morphology  MGI:2139806
#
#                 mp
# 83736   MP:0000003
# 103676  MP:0000003
# 40413   MP:0000003
# 16235   MP:0000003
# 188573  MP:0000003

# %%
human = pd.read_csv("../files/HMD_HumanPhenotype_Jan16_2020.rpt", 
                    sep="\t", header=None,
                    names=['gene','entrez','entrez_2','yes/no','mouse_gene','mgi','mp','other']
                   )
human = human.drop(["other", "mp"], axis=1)
human["mgi"] = human["mgi"].str.replace(" ", "")
human.head()
# Out:
#       gene  entrez  entrez_2 yes/no mouse_gene          mgi
# 0     A1BG       1   11167.0    yes       A1bg  MGI:2152878
# 1     A1CF   29974   16363.0    yes       A1cf  MGI:1917115
# 2      A2M       2   37248.0    yes        A2m  MGI:2449119
# 3  A3GALT2  127550   16326.0    yes    A3galt2  MGI:2685279
# 4   A4GALT   53947    9690.0    yes     A4galt  MGI:3512453

# %%
human_mouse = pd.merge(human,mgi_batch_report_parsed,on=['mgi'])
human_mouse
# Out:
#          gene  entrez  entrez_2 yes/no mouse_gene          mgi database  \
# 0        A1CF   29974   16363.0    yes       A1cf  MGI:1917115      MGI
# 1        A1CF   29974   16363.0    yes       A1cf  MGI:1917115      MGI
# 2        A1CF   29974   16363.0    yes       A1cf  MGI:1917115      MGI
# 3        A1CF   29974   16363.0    yes       A1cf  MGI:1917115      MGI
# 4        A1CF   29974   16363.0    yes       A1cf  MGI:1917115      MGI
# ...       ...     ...       ...    ...        ...          ...      ...
# 194859  ZZEF1   23140    9027.0    yes      Zzef1  MGI:2444286      MGI
# 194860  ZZEF1   23140    9027.0    yes      Zzef1  MGI:2444286      MGI
# 194861  ZZEF1   23140    9027.0    yes      Zzef1  MGI:2444286      MGI
# 194862  ZZEF1   23140    9027.0    yes      Zzef1  MGI:2444286      MGI
# 194863   ZZZ3   26009    9182.0    yes       Zzz3  MGI:1920453      MGI
#
#                                                   geneset          mp
# 0                 MP:0000352_decreased_cell_proliferation  MP:0000352
# 1                       MP:0002795_dilated_cardiomyopathy  MP:0002795
# 2       MP:0005140_decreased_cardiac_muscle_contractility  MP:0005140
# 3         MP:0005329_abnormal_myocardium_layer_morphology  MP:0005329
# 4       MP:0011094_embryonic_lethality_before_implanta...  MP:0011094
# ...                                                   ...         ...
# 194859         MP:0010025_decreased_total_body_fat_amount  MP:0010025
# 194860                 MP:0010053_decreased_grip_strength  MP:0010053
# 194861                 MP:0011396_abnormal_sleep_behavior  MP:0011396
# 194862                            MP:0030610_absent_teeth  MP:0030610
# 194863  MP:0011100_preweaning_lethality,_complete_pene...  MP:0011100
#
# [194864 rows x 9 columns]

# %%
human_mouse = human_mouse[['gene','entrez','mgi','geneset']]
human_mouse.columns = ["gene_symbol", "EntrezID", "mgi", "geneset"]
human_mouse.head()
# Out:
#   gene_symbol  EntrezID          mgi  \
# 0        A1CF     29974  MGI:1917115
# 1        A1CF     29974  MGI:1917115
# 2        A1CF     29974  MGI:1917115
# 3        A1CF     29974  MGI:1917115
# 4        A1CF     29974  MGI:1917115
#
#                                              geneset
# 0            MP:0000352_decreased_cell_proliferation
# 1                  MP:0002795_dilated_cardiomyopathy
# 2  MP:0005140_decreased_cardiac_muscle_contractility
# 3    MP:0005329_abnormal_myocardium_layer_morphology
# 4  MP:0011094_embryonic_lethality_before_implanta...

# %%
len(human_mouse)
# Out:
# 194864

# %%
mapping_df = pd.read_csv("/data/Segre_Lab/scripts/GeneEnrich/data/entrez_ensembl_mapping_v26_16Jun_2022.txt", sep="\t")
mapping_df.head()
# Out:
#    EntrezID  ensembl_gene_id gene_symbol
# 0         1  ENSG00000121410        A1BG
# 1         2  ENSG00000175899         A2M
# 2         3  ENSG00000256069       A2MP1
# 3         9  ENSG00000171428        NAT1
# 4        10  ENSG00000156006        NAT2

# %%
x = pd.merge(human_mouse, mapping_df, on=["EntrezID", "gene_symbol"])

# %%
x
# Out:
#        gene_symbol  EntrezID          mgi  \
# 0             A1CF     29974  MGI:1917115
# 1             A1CF     29974  MGI:1917115
# 2             A1CF     29974  MGI:1917115
# 3             A1CF     29974  MGI:1917115
# 4             A1CF     29974  MGI:1917115
# ...            ...       ...          ...
# 192341       ZZEF1     23140  MGI:2444286
# 192342       ZZEF1     23140  MGI:2444286
# 192343       ZZEF1     23140  MGI:2444286
# 192344       ZZEF1     23140  MGI:2444286
# 192345        ZZZ3     26009  MGI:1920453
#
#                                                   geneset  ensembl_gene_id
# 0                 MP:0000352_decreased_cell_proliferation  ENSG00000148584
# 1                       MP:0002795_dilated_cardiomyopathy  ENSG00000148584
# 2       MP:0005140_decreased_cardiac_muscle_contractility  ENSG00000148584
# 3         MP:0005329_abnormal_myocardium_layer_morphology  ENSG00000148584
# 4       MP:0011094_embryonic_lethality_before_implanta...  ENSG00000148584
# ...                                                   ...              ...
# 192341         MP:0010025_decreased_total_body_fat_amount  ENSG00000074755
# 192342                 MP:0010053_decreased_grip_strength  ENSG00000074755
# 192343                 MP:0011396_abnormal_sleep_behavior  ENSG00000074755
# 192344                            MP:0030610_absent_teeth  ENSG00000074755
# 192345  MP:0011100_preweaning_lethality,_complete_pene...  ENSG00000036549
#
# [192346 rows x 5 columns]

# %%
len(x["geneset"].unique())
# Out:
# 9970

# %%
x = x.loc[x["mgi"].isin(mouse_mgi_ids["MGI_Marker_Accession_ID"])]

# %%
len(x)
# Out:
# 192346

# %%
len(x["geneset"].unique())
# Out:
# 9970
